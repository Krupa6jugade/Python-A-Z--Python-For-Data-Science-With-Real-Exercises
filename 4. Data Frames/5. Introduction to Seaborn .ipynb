# %%
import pandas as pd

# %%
stats = pd.read_csv('DemographicData.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline 
plt.rcParams['figure.figsize'] = 12,6
import warnings
warnings.filterwarnings('ignore')

# %%
#Distribution

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
vis1 = sns.distplot(stats['Internet users'])

# %%
vis1 = sns.distplot(stats['Internet users'],bins=30)

# %%
vis1 = sns.distplot(stats['Internet users'],bins= 30)

# %%
vis2 = sns.boxplot(data = stats, x ='Income Group', y = 'Birth rate')

# %% [markdown]
# # https://seaborn.pydata.org/examples/

# %% [raw]
# #Visualizing With Seaborn: Part 1

# %%
vis3 = sns.lmplot(data = stats,x = 'Birth rate',y= 'Internet users')

# %%
vis3 = sns.lmplot(data = stats,x = 'Birth rate',y= 'Internet users',fit_reg=False)

# %%
vis3 = sns.lmplot(data = stats,x = 'Internet users',y= 'Birth rate',\
                  fit_reg=False,hue='Income Group',size=7,aspect=1)

# %% [markdown]
# # Keyword Arguments in Python (advanced tutorial)

# %%
vis3 = sns.lmplot(data = stats,x = 'Internet users',y= 'Birth rate',\
                  fit_reg=False,hue='Income Group',size=7,aspect=1,\
                scatter_kws={"s":200})
