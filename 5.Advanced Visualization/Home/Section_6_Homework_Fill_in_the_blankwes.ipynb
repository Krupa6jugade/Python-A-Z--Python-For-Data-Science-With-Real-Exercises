# %% [markdown]
# ### Section 6 Homework - Fill in the blanks

# %% [markdown]
# Import the packages needed to perform the analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Import the data
mov = pd.read_csv('Section6-Homework-Data.csv', encoding = 'latin1')

# %%
# Explore the dataset
mov.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# 0         202.1          6.7              3.26            111.9       55.4
# 1         203.3          6.6              2.97            159.7       78.6
# 2         206.2          6.1              2.93            166.9       80.9
# 3         201.6          7.2              3.62             63.1       31.3
# 4         205.4          8.0              3.65            132.3       64.4
#
#   Profit ($mill)  Profit%  Runtime (min)  US ($mill)  Gross % US
# 0           32.1     18.9            130        90.2        44.6
# 1          137.3    208.0            132        43.6        21.4
# 2          106.2    106.2            126        39.3        19.1
# 3          159.6    380.0            109       138.4        68.7
# 4           55.4     36.9            131        73.1        35.6

# %%
# Check the summary of the dataframe
mov.describe()
# Out:
#        Budget ($mill)  IMDb Rating  MovieLens Rating   Overseas%  \
# count      608.000000   608.000000        608.000000  608.000000
# mean        92.467928     6.923849          3.340378   57.698849
# std         59.421407     0.925890          0.454071   12.334237
# min          0.600000     3.600000          1.490000   17.200000
# 25%         45.000000     6.375000          3.037500   49.900000
# 50%         80.000000     6.900000          3.365000   58.200000
# 75%        130.000000     7.600000          3.672500   66.300000
# max        300.000000     9.200000          4.500000  100.000000
#
#             Profit%  Runtime (min)  US ($mill)  Gross % US
# count    608.000000     608.000000  608.000000  608.000000
# mean     719.278783     117.781250  167.135197   42.301151
# std     1942.807248      23.179122   92.465903   12.334237
# min        7.700000      30.000000    0.000000    0.000000
# 25%      201.850000     100.000000  106.950000   33.700000
# 50%      338.550000     116.000000  141.700000   41.800000
# 75%      650.100000     130.250000  202.100000   50.100000
# max    41333.300000     238.000000  760.500000   82.800000

# %%
# Check the structure of the dataframe
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# Day of Week               608 non-null object
# Director                  608 non-null object
# Genre                     608 non-null object
# Movie Title               608 non-null object
# Release Date              608 non-null object
# Studio                    608 non-null object
# Adjusted Gross ($mill)    608 non-null object
# Budget ($mill)            608 non-null float64
# Gross ($mill)             608 non-null object
# IMDb Rating               608 non-null float64
# MovieLens Rating          608 non-null float64
# Overseas ($mill)          608 non-null object
# Overseas%                 608 non-null float64
# Profit ($mill)            608 non-null object
# Profit%                   608 non-null float64
# Runtime (min)             608 non-null int64
# US ($mill)                608 non-null float64
# Gross % US                608 non-null float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 85.6+ KB

# %%
vis1 = sns.factorplot(data =mov,x = 'Day of Week',kind='count',size=7)

# %%
# Explore the categorical variable Studio, used in the assignment
mov.Studio.unique()
# Out:
# array(['Buena Vista Studios', 'Lionsgate', 'Sony', 'Universal',
#        'Paramount Pictures', 'WB', 'Weinstein Company',
#        'UA Entertainment', 'WB/New Line', 'New Line Cinema', 'Fox',
#        'TriStar', 'Relativity Media', 'Screen Gems', 'StudioCanal',
#        'Fox Searchlight Pictures', 'MiraMax', 'Path_ Distribution',
#        'DreamWorks', 'Lionsgate Films', 'Revolution Studios',
#        'Dimension Films', 'USA', 'Lionsgate/Summit',
#        'Sony Picture Classics', 'Pacific Data/DreamWorks', 'Disney',
#        'Art House Studios', 'Colombia Pictures', 'Gramercy Pictures',
#        'Summit Entertainment', 'Vestron Pictures', 'MGM', 'Orion', 'IFC',
#        'New Market Films'], dtype=object)

# %%
len(mov.Studio.unique())
# Out:
# 36

# %%
# Explore the categorical variable Studio, used in the assignment
mov.Genre.unique()
# Out:
# array(['action', 'comedy', 'adventure', 'horror', 'animation',
#        'biography', 'drama', 'musical', 'sci-fi', 'crime', 'romance',
#        'fantasy', 'mystery', 'thriller', 'documentary'], dtype=object)

# %%
len(mov.Genre.unique())
# Out:
# 15

# %%
# Filter the dataframe by studio
mov2 = mov[(mov.Studio == 'Buena Vista Studios') | (mov.Studio == 'Fox') | (mov.Studio == 'Paramount Pictures') | (mov.Studio == 'Sony') | (mov.Studio == 'Universal') | (mov.Studio == 'WB')]

# %%
mov2.Studio.unique()
# Out:
# array(['Buena Vista Studios', 'Sony', 'Universal', 'Paramount Pictures',
#        'WB', 'Fox'], dtype=object)

# %%
mov2
# Out:
#     Day of Week                     Director      Genre  \
# 0        Friday                    Brad Bird     action
# 1        Friday                  Scott Waugh     action
# 3        Friday      Phil Lord, Chris Miller     comedy
# 4        Friday              Roland Emmerich     action
# 5        Friday                   David Ayer     action
# 6      Thursday                 Rob Marshall  adventure
# 7        Friday              Daniel Espinosa     action
# 8        Friday                   Gary Shore     action
# 9        Friday  Henry Joost, Ariel Schulman     horror
# 10       Friday                  Eric Brevig  animation
# 14       Friday                  Ryan Murphy      drama
# 15       Friday              Paul Greengrass      drama
# 16       Friday               Hayao Miyazaki  animation
# 17       Friday           Jaume Collet-Serra     action
# 18       Friday           Jonathan Liebesman     action
# 19       Friday        Christopher McQuarrie     action
# 20       Friday                 Dennis Dugan     comedy
# 21       Friday               Robert Luketic     comedy
# 22       Friday                  Jake Kasdan     comedy
# 23    Wednesday                  Tate Taylor      drama
# 24       Friday                Todd Phillips     comedy
# 25       Friday                Tommy Wirkola     action
# 27       Friday              Martin Campbell     action
# 28    Wednesday                 Baz Luhrmann  adventure
# 30       Friday                    Paul Feig     action
# 31    Wednesday               Jon Turteltaub     action
# 32     Thursday                Adam Shankman     comedy
# 33       Friday               Garry Marshall     comedy
# 34    Wednesday                 Michael Mann  biography
# 36       Friday                  Ben Affleck      drama
# ..          ...                          ...        ...
# 570      Friday                   Tim Burton  adventure
# 571      Friday            Christopher Nolan     action
# 572   Wednesday             Richard Marquand     action
# 573    Thursday                   Sam Mendes     action
# 575      Friday                  Lee Unkrich  animation
# 576      Friday               Chris Columbus  adventure
# 580      Friday  Andrew Stanton, Lee Unkrich  animation
# 582   Wednesday              Roland Emmerich     action
# 583      Friday                  Shane Black     action
# 584      Friday              Colin Trevorrow     action
# 585      Friday               Gore Verbinski     action
# 586      Friday     Chris Buck, Jennifer Lee  animation
# 587      Friday               Chris Columbus  adventure
# 588      Friday                  Joss Whedon     action
# 589   Wednesday         Francis Ford Coppola      crime
# 590      Friday                  David Yates    fantasy
# 591      Friday               Randal Kleiser    musical
# 593   Wednesday                 George Lucas     sci-fi
# 594      Friday                    James Wan     action
# 595   Wednesday               Irvin Kershner     sci-fi
# 596      Friday                  Joss Whedon     action
# 597   Wednesday    Roger Allers, Rob Minkoff  animation
# 598      Friday             Steven Spielberg  adventure
# 600      Friday             Steven Spielberg  adventure
# 601      Friday             Steven Spielberg   thriller
# 602     Tuesday            Richard Fleischer  adventure
# 603   Wednesday             William Friedkin     horror
# 604   Wednesday                 George Lucas     action
# 605      Friday                James Cameron     sci-fi
# 606   Wednesday                James Cameron      drama
#
#                                      Movie Title Release Date  \
# 0                                   Tomorrowland   22/05/2015
# 1                                 Need for Speed   14/03/2014
# 3                                 21 Jump Street   16/03/2012
# 4                               White House Down   28/06/2013
# 5                                           Fury   17/10/2014
# 6                                 Into the Woods   25/12/2014
# 7                                     Safe House   10/02/2012
# 8                                 Dracula Untold   10/10/2014
# 9                          Paranormal Activity 3   21/10/2011
# 10                                     Yogi Bear   17/12/2010
# 14                                 Eat Pray Love   13/08/2010
# 15                              Captain Phillips   11/10/2013
# 16                                         Ponyo   14/08/2009
# 17                                      Non-Stop   28/02/2014
# 18                           Battle: Los Angeles   11/03/2011
# 19                                  Jack Reacher   21/12/2012
# 20                               Just Go With It   11/02/2011
# 21                                The Ugly Truth   24/07/2009
# 22                                   Bad Teacher   24/06/2011
# 23                                      The Help   10/08/2011
# 24                                      Due Date    5/11/2010
# 25              Hansel and Gretel: Witch Hunters   25/01/2013
# 27                                 Green Lantern   17/06/2011
# 28                                     Australia   26/11/2008
# 30                                      The Heat   28/06/2013
# 31                     The Sorcerer's Apprentice   14/07/2010
# 32                               Bedtime Stories   25/12/2008
# 33                               Valentine's Day   12/02/2010
# 34                                Public Enemies    1/07/2009
# 36                                          Argo   12/10/2012
# ..                                           ...          ...
# 570                          Alice in Wonderland    5/03/2010
# 571                        The Dark Knight Rises   20/07/2012
# 572                           Return of the Jedi   25/05/1983
# 573                                      Skyfall    8/11/2012
# 575                                  Toy Story 3   18/06/2010
# 576      Harry Potter and the Chamber of Secrets   15/11/2002
# 580                                 Finding Nemo   30/05/2003
# 582                             Independence Day    3/07/1996
# 583                                   Iron Man 3    3/05/2013
# 584                               Jurassic World   12/06/2015
# 585   Pirates of the Caribbean: Dead Man's Chest    7/07/2006
# 586                                       Frozen   22/11/2013
# 587        Harry Potter and the Sorcerer's Stone   16/11/2001
# 588                      Avengers: Age of Ultron    1/05/2015
# 589                                The Godfather   15/03/1972
# 590  Harry Potter and the Deathly Hallows Part 2   15/07/2011
# 591                                       Grease   16/06/1978
# 593    Star Wars: Episode I - The Phantom Menace   19/05/1999
# 594                                    Furious 7    3/04/2015
# 595                      The Empire Strikes Back   21/05/1980
# 596                        Marvel's The Avengers    4/05/2012
# 597                                The Lion King   15/06/1994
# 598                                Jurassic Park   11/06/1993
# 600                  E.T.: The Extra-Terrestrial   11/06/1982
# 601                                         Jaws   20/06/1975
# 602                              Doctor Dolittle   19/12/1967
# 603                                 The Exorcist   26/12/1973
# 604                                    Star Wars   25/05/1977
# 605                                       Avatar   18/12/2009
# 606                                      Titanic   17/12/1997
#
#                   Studio Adjusted Gross ($mill)  Budget ($mill) Gross ($mill)  \
# 0    Buena Vista Studios                  202.1           170.0         202.1
# 1    Buena Vista Studios                  204.2            66.0         203.3
# 3                   Sony                  208.8            42.0         201.6
# 4                   Sony                  209.7           150.0         205.4
# 5                   Sony                  212.8            80.0         211.8
# 6    Buena Vista Studios                  213.9            50.0         212.9
# 7              Universal                  215.5            85.0         208.1
# 8              Universal                  216.5            70.0         215.5
# 9     Paramount Pictures                  218.8             5.0           207
# 10                    WB                  219.9            80.0         201.6
# 14                  Sony                  223.1            60.0         204.6
# 15                  Sony                  223.4            55.0         218.8
# 16   Buena Vista Studios                  223.7            34.0         201.8
# 17             Universal                  223.8            50.0         222.8
# 18                  Sony                  223.9            70.0         211.8
# 19    Paramount Pictures                  226.1            60.0         218.3
# 20                  Sony                  227.2            80.0         214.9
# 21                  Sony                  227.6            38.0         205.3
# 22                  Sony                  228.6            19.0         216.2
# 23   Buena Vista Studios                    229            25.0         216.6
# 24                    WB                    231            65.0         211.8
# 25    Paramount Pictures                    231            50.0         226.3
# 27                    WB                  232.5           200.0         219.9
# 28                   Fox                  233.4            78.0         211.3
# 30                   Fox                  234.7            43.0         229.9
# 31   Buena Vista Studios                  234.8           160.0         215.3
# 32   Buena Vista Studios                  235.2            80.0         212.9
# 33                    WB                  236.1            52.0         216.5
# 34             Universal                  237.3           102.5         214.1
# 36                    WB                  240.6            44.5         232.3
# ..                   ...                    ...             ...           ...
# 570  Buena Vista Studios               1,118.40           200.0      1,025.50
# 571                   WB               1,123.20           275.0      1,084.40
# 572                  Fox               1,134.30            32.5         475.1
# 573                 Sony               1,148.20           200.0      1,108.60
# 575  Buena Vista Studios               1,159.50           200.0      1,063.20
# 576                   WB               1,161.90           100.0           879
# 580  Buena Vista Studios               1,210.60            94.0         936.7
# 582                  Fox               1,238.90            75.0         817.4
# 583  Buena Vista Studios               1,240.70           200.0      1,215.40
# 584            Universal               1,245.90           215.0      1,245.90
# 585  Buena Vista Studios               1,257.70           225.0      1,066.20
# 586  Buena Vista Studios               1,300.70           150.0      1,274.20
# 587                   WB               1,308.90           125.0         974.8
# 588  Buena Vista Studios               1,371.60           250.0      1,371.60
# 589   Paramount Pictures               1,394.40             7.0         245.1
# 590                   WB               1,418.20           125.0      1,341.50
# 591   Paramount Pictures               1,440.70             6.0           395
# 593                  Fox               1,465.90           115.0         1,027
# 594            Universal               1,511.60           190.0      1,511.60
# 595                  Fox               1,553.80            23.0         538.4
# 596  Buena Vista Studios               1,572.90           220.0      1,518.60
# 597  Buena Vista Studios               1,584.60            79.3         987.5
# 598            Universal               1,693.80            63.0      1,029.20
# 600            Universal               1,953.90            10.5         792.9
# 601            Universal               2,080.60            12.0         470.7
# 602                  Fox               2,096.80            70.5         294.5
# 603                   WB               2,363.60            12.0         441.3
# 604                  Fox               3,042.80            11.0         775.4
# 605                  Fox               3,090.40           237.0         2,788
# 606   Paramount Pictures               3,240.10           200.0      2,186.80
#
#      IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas% Profit ($mill)  \
# 0            6.7              3.26            111.9       55.4           32.1
# 1            6.6              2.97            159.7       78.6          137.3
# 3            7.2              3.62             63.1       31.3          159.6
# 4            8.0              3.65            132.3       64.4           55.4
# 5            5.8              2.85              126       59.5          131.8
# 6            6.0              3.16             84.9       39.9          162.9
# 7            6.8              3.45             81.7       39.3          123.1
# 8            6.3              2.92            159.2       73.9          145.5
# 9            5.9              2.90              103       49.8            202
# 10           4.5              2.17            101.3       50.3          121.6
# 14           5.6              2.84              124       60.6          144.6
# 15           7.9              3.84            111.7       51.0          163.8
# 16           7.7              3.82            186.7       92.5          167.8
# 17           7.0              3.40            130.6       58.6          172.8
# 18           7.6              3.65            128.3       60.6          141.8
# 19           7.0              3.46            138.3       63.3          158.3
# 20           6.4              3.17            111.9       52.1          134.9
# 21           6.5              3.21            116.4       56.7          167.3
# 22           5.7              2.96            115.9       53.6          197.2
# 23           8.1              3.93             46.9       21.7          191.6
# 24           6.6              3.17            111.2       52.5          146.8
# 25           6.1              2.90            170.6       75.4          176.3
# 27           5.7              2.87            103.3       47.0           19.9
# 28           7.6              3.50            161.8       76.6          133.3
# 30           6.6              4.07             70.3       30.6          186.9
# 31           7.1              3.48            152.1       70.7           55.3
# 32           6.1              3.12            102.8       48.3          132.9
# 33           5.8              3.00              106       49.0          164.5
# 34           7.0              3.36              117       54.6          111.6
# 36           7.8              3.90             96.3       41.5          187.8
# ..           ...               ...              ...        ...            ...
# 570          6.5              3.27            691.3       67.4          825.5
# 571          8.5              4.01            636.3       58.7          809.4
# 572          8.4              3.99            165.8       34.9          442.6
# 573          7.8              3.81            804.2       72.5          908.6
# 575          8.4              4.01            648.2       61.0          863.2
# 576          7.3              3.58              617       70.2            779
# 580          8.2              3.89            555.9       59.3          842.7
# 582          6.9              3.40            511.2       62.5          742.4
# 583          7.3              3.68            806.4       66.3       1,015.40
# 584          7.5              3.45            745.5       59.8       1,030.90
# 585          7.3              3.47            642.9       60.3          841.2
# 586          7.7              3.71            873.5       68.6       1,124.20
# 587          7.5              3.62            657.2       67.4          849.8
# 588          7.9              3.75            919.1       67.0       1,121.60
# 589          9.2              4.36            110.1       44.9          238.1
# 590          8.1              3.96            960.5       71.6       1,216.50
# 591          7.2              3.31            206.2       52.2            389
# 593          6.6              3.10            552.5       53.8            912
# 594          7.6              3.34         1,160.60       76.8       1,321.60
# 595          8.8              4.18            247.9       46.0          515.4
# 596          8.2              3.95            895.2       59.0       1,298.60
# 597          8.5              3.78            564.7       57.2          908.2
# 598          8.1              3.66            626.7       60.9          966.2
# 600          7.9              3.76            357.8       45.1          782.4
# 601          8.1              3.81            210.7       44.8          458.7
# 602          5.3              3.01            150.3       51.0            224
# 603          6.9              3.39            208.4       47.2          429.3
# 604          8.7              4.19            314.4       40.5          764.4
# 605          7.9              3.78         2,027.50       72.7          2,551
# 606          7.7              3.38         1,528.10       69.9       1,986.80
#
#      Profit%  Runtime (min)  US ($mill)  Gross % US
# 0       18.9            130        90.2        44.6
# 1      208.0            132        43.6        21.4
# 3      380.0            109       138.4        68.7
# 4       36.9            131        73.1        35.6
# 5      164.8            134        85.8        40.5
# 6      325.8            125       128.0        60.1
# 7      144.8            115       126.4        60.7
# 8      207.9             92        56.3        26.1
# 9     4040.0             84       104.0        50.2
# 10     152.0             80       100.2        49.7
# 14     241.0            133        80.6        39.4
# 15     297.8            134       107.1        49.0
# 16     493.5            101        15.1         7.5
# 17     345.6            106        92.2        41.4
# 18     202.6            116        83.6        39.4
# 19     263.8            130        80.1        36.7
# 20     168.6            117       103.0        47.9
# 21     440.3             96        88.9        43.3
# 22    1037.9             92       100.3        46.4
# 23     766.4            146       169.7        78.3
# 24     225.9             95       100.5        47.5
# 25     352.6             88        55.7        24.6
# 27      10.0            114       116.6        53.0
# 28     170.9            165        49.6        23.4
# 30     434.7            117       159.6        69.4
# 31      34.6            109        63.2        29.3
# 32     166.1             99       110.1        51.7
# 33     316.4            125       110.5        51.0
# 34     108.9            140        97.1        45.4
# 36     422.0            120       136.0        58.5
# ..       ...            ...         ...         ...
# 570    412.8            108       334.2        32.6
# 571    294.3            165       448.1        41.3
# 572   1361.9            134       309.3        65.1
# 573    454.3            143       304.4        27.5
# 575    431.6            103       415.0        39.0
# 576    779.0            161       262.0        29.8
# 580    896.5            100       380.8        40.7
# 582    989.9            145       306.2        37.5
# 583    507.7            130       409.0        33.7
# 584    479.5            124       500.4        40.2
# 585    373.9            151       423.3        39.7
# 586    749.5            102       400.7        31.4
# 587    679.8            152       317.6        32.6
# 588    448.6            141       452.5        33.0
# 589   3401.4            175       135.0        55.1
# 590    973.2            130       381.0        28.4
# 591   6483.3            110       188.8        47.8
# 593    793.0            136       474.5        46.2
# 594    695.6            137       351.0        23.2
# 595   2240.9            124       290.5        54.0
# 596    590.3            143       623.4        41.0
# 597   1145.3             89       422.8        42.8
# 598   1533.7            127       402.5        39.1
# 600   7451.4            115       435.1        54.9
# 601   3822.5            124       260.0        55.2
# 602    317.7            152       144.2        49.0
# 603   3577.5            122       232.9        52.8
# 604   6949.1            121       461.0        59.5
# 605   1076.4            162       760.5        27.3
# 606    993.4            194       658.7        30.1
#
# [477 rows x 18 columns]

# %%
genre

# %%
# Filter the dataframe by genre
mov2 = mov[(mov._ == 'action') | (mov._ == 'adventure') | (mov._ == 'animation') | (mov._ == 'comedy') | (mov._ == 'drama')]

# %%
# Check how the filters worked
print (_.Genre.unique())
print (_.Studio.unique())
print (len(_))

# %%
# Define the style
_.set(style="darkgrid", palette="muted", color_codes=True)

# Plot the boxsplots
ax = sns._(data=_, x='_', y='_', orient='v', color='lightgray', showfliers=False)
plt.setp(ax.artists, alpha=0.5)

# Add in points to show each observation
_.stripplot(x='_', y='_', data=_, jitter=True, size=6, linewidth=0, hue = 'Studio', alpha=0.7)

ax.axes.set_title('_',fontsize=30)
ax.set_xlabel('_',fontsize=20)
ax.set_ylabel('_',fontsize=20)

# Define where to place the legend
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
